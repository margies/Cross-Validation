# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from glob import glob
import pandas as pd
from scipy import spatial
import operator
from nltk.corpus import stopwords

# %% [markdown]
# ## Part I: IDF

# %% [markdown]
# Stop words and symbols

# %%
# C Language's Keywords
keyword = ["auto","break","case","char","const","continue","default","do","double","else","enum","extern","float","for","goto","if","int","long","register","return","short","signed","sizeof","static","struct","switch","typedef","union","unsigned","void","volatile","while", "1", "2", "3", "4", "5", "6", "7", "8", "9", "0"]
# english stop word
keyword += stopwords.words('english')
sym = ["+", "@", "~", "*", "-", "/", "#", "{", "}", "(", ")", ";", ">", "<", "=", ":", "!", "|", "?", "'", '"', ".", ","]

# %% [markdown]
# File Preprocessing

# %%
# Load all files
files = glob(".\IS706\documents\*.txt")
data = []
filename = []
for file in files:
    filename.append(file.replace(".\\IS706\\documents\\", ""))
    with open(file) as doc:
        # Lowercase
        content = doc.read().lower().strip()
        # Remove symbol
        for symbol in sym:
            content = content.replace(symbol, " ")
        # Remove stopwords and \n, \t
        content = content.replace("\n", " ").replace("\\n", " ").replace("\t", " ").split(" ")
        content = " ".join([w for w in content if w != "" and w[0] not in "0123456789" and w not in keyword and len(w) > 1])

    data.append(content)
data
# Out:
# ['init crypto authenc module init crypto template crypto authenc tmpl',
#  'snd rawmidi ioctl status compat snd rawmidi file rfile snd rawmidi status32 user src err snd rawmidi status status rfile output null einval get user status stream src stream efault status stream sndrv rawmidi stream output err snd rawmidi output status rfile output status sndrv rawmidi stream input err snd rawmidi input status rfile input status einval err err put user status tstamp tv sec src tstamp tv sec put user status tstamp tv nsec src tstamp tv nsec put user status avail src avail put user status xruns src xruns efault',
#  'snd ctl make virtual master create virtual master control name name string control element create tlv optional tlv array db information creates virtual matster control given name string returns created control element null errors enomem creating vmaster element add slave controls via snd ctl add slave snd ctl add slave uncached optional argument tlv used specify tlv information db scale master control single element sndrv ctl tlvt db scale sndrv ctl tlv db minmax sndrv ctl tlvt db minmax mute type max snd kcontrol snd ctl make virtual master name tlv link master master snd kcontrol kctl snd kcontrol new knew memset knew knew knew iface sndrv ctl elem iface mixer knew name name knew info master info master kzalloc master gfp kernel master null init list head master slaves kctl snd ctl new1 knew master kctl kfree master null override callbacks kctl info master info kctl get master get kctl put master put kctl private free master free additional constant tlv read tlv tlv sndrv ctl tlvt db scale tlv sndrv ctl tlvt db minmax tlv sndrv ctl tlvt db minmax mute kctl vd access sndrv ctl elem access tlv read memcpy master tlv tlv master tlv kctl tlv master tlv kctl',
#  'crypto rfc4106 init tfm crypto tfm tfm crypto instance inst tfm crt alg crypto aead spawn spawn crypto instance ctx inst crypto rfc4106 ctx ctx crypto tfm ctx tfm crypto aead aead align aead crypto spawn aead spawn err aead ptr err aead ctx child aead align crypto aead alignmask aead align crypto tfm ctx alignment tfm crt aead reqsize aead request align crypto aead reqsize aead crypto tfm ctx alignment align',
#  'snd ensoniq playback2 prepare snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream snd pcm runtime runtime substream runtime mode ensoniq p2 dma size snd pcm lib buffer bytes substream ensoniq p2 period size snd pcm lib period bytes substream snd pcm format width runtime format mode runtime channels mode spin lock irq ensoniq reg lock ensoniq ctrl es dac2 en outl ensoniq ctrl es reg ensoniq control outl es mem pageo es page dac es reg ensoniq mem page outl runtime dma addr es reg ensoniq dac2 frame outl ensoniq p2 dma size es reg ensoniq dac2 size ensoniq sctrl es p2 loop sel es p2 pause es p2 dac sen es p2 end incm es p2 st incm es p2 modem ensoniq sctrl es p2 en es p2 modeo mode es p2 end inco mode es p2 st inco outl ensoniq sctrl es reg ensoniq serial outl ensoniq p2 period size snd ensoniq sample shift mode es reg ensoniq dac2 count ifdef chip1370 ensoniq es1370 pclkdiv lock es mode capture ensoniq ctrl es pclkdivm ensoniq ctrl es pclkdivo es srtodiv runtime rate ensoniq es1370 pclkdiv lock es mode play2 endif outl ensoniq ctrl es reg ensoniq control spin unlock irq ensoniq reg lock ifndef chip1370 snd es1371 dac2 rate ensoniq runtime rate endif',
#  'snd ensoniq capture prepare snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream snd pcm runtime runtime substream runtime mode ensoniq dma size snd pcm lib buffer bytes substream ensoniq period size snd pcm lib period bytes substream snd pcm format width runtime format mode runtime channels mode spin lock irq ensoniq reg lock ensoniq ctrl es adc en outl ensoniq ctrl es reg ensoniq control outl es mem pageo es page adc es reg ensoniq mem page outl runtime dma addr es reg ensoniq adc frame outl ensoniq dma size es reg ensoniq adc size ensoniq sctrl es r1 loop sel es r1 modem ensoniq sctrl es r1 en es r1 modeo mode outl ensoniq sctrl es reg ensoniq serial outl ensoniq period size snd ensoniq sample shift mode es reg ensoniq adc count ifdef chip1370 ensoniq es1370 pclkdiv lock es mode play2 ensoniq ctrl es pclkdivm ensoniq ctrl es pclkdivo es srtodiv runtime rate ensoniq es1370 pclkdiv lock es mode capture endif outl ensoniq ctrl es reg ensoniq control spin unlock irq ensoniq reg lock ifndef chip1370 snd es1371 adc rate ensoniq runtime rate endif',
#  'snd pcm uframes snd ensoniq playback1 pointer snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream size ptr spin lock ensoniq reg lock inl es reg ensoniq control es dac1 en outl es mem pageo es page dac es reg ensoniq mem page ptr es reg fcurr counti inl es reg ensoniq dac1 size ptr bytes frames substream runtime ptr ptr spin unlock ensoniq reg lock ptr',
#  'snd pcm uframes snd ensoniq playback2 pointer snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream size ptr spin lock ensoniq reg lock inl es reg ensoniq control es dac2 en outl es mem pageo es page dac es reg ensoniq mem page ptr es reg fcurr counti inl es reg ensoniq dac2 size ptr bytes frames substream runtime ptr ptr spin unlock ensoniq reg lock ptr',
#  'snd pcm uframes snd ensoniq capture pointer snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream size ptr spin lock ensoniq reg lock inl es reg ensoniq control es adc en outl es mem pageo es page adc es reg ensoniq mem page ptr es reg fcurr counti inl es reg ensoniq adc size ptr bytes frames substream runtime ptr ptr spin unlock ensoniq reg lock ptr',
#  'snd ensoniq playback1 open snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream snd pcm runtime runtime substream runtime ensoniq mode es mode play1 ensoniq playback1 substream substream runtime hw snd ensoniq playback1 snd pcm set sync substream spin lock irq ensoniq reg lock ensoniq spdif ensoniq playback2 substream null ensoniq spdif stream ensoniq spdif spin unlock irq ensoniq reg lock ifdef chip1370 snd pcm hw constraint list runtime sndrv pcm hw param rate snd es1370 hw constraints rates snd pcm hw constraint ratdens runtime sndrv pcm hw param rate snd es1371 hw constraints dac clock endif',
#  'snd pcm set sync snd pcm substream substream',
#  'snd ensoniq playback2 open snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream snd pcm runtime runtime substream runtime ensoniq mode es mode play2 ensoniq playback2 substream substream runtime hw snd ensoniq playback2 snd pcm set sync substream spin lock irq ensoniq reg lock ensoniq spdif ensoniq playback1 substream null ensoniq spdif stream ensoniq spdif spin unlock irq ensoniq reg lock ifdef chip1370 snd pcm hw constraint ratnums runtime sndrv pcm hw param rate snd es1370 hw constraints clock snd pcm hw constraint ratdens runtime sndrv pcm hw param rate snd es1371 hw constraints dac clock endif',
#  'snd ensoniq capture open snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream snd pcm runtime runtime substream runtime ensoniq mode es mode capture ensoniq capture substream substream runtime hw snd ensoniq capture snd pcm set sync substream ifdef chip1370 snd pcm hw constraint ratnums runtime sndrv pcm hw param rate snd es1370 hw constraints clock snd pcm hw constraint ratnums runtime sndrv pcm hw param rate snd es1371 hw constraints adc clock endif',
#  'inline u32 crypto ahash get flags crypto ahash tfm crypto tfm get flags crypto ahash tfm tfm',
#  'snd pcm hw constraint ratnums snd pcm runtime runtime cond snd pcm hw param var snd pcm hw constraint ratnums',
#  'crypto rfc4106 exit tfm crypto tfm tfm crypto rfc4106 ctx ctx crypto tfm ctx tfm crypto free aead ctx child',
#  'snd ensoniq playback1 close snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream ensoniq playback1 substream null ensoniq mode es mode play1',
#  'pcie set ecrc checking pci dev dev',
#  'snd ensoniq playback2 close snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream ensoniq playback2 substream null spin lock irq ensoniq reg lock ifdef chip1370 ensoniq es1370 pclkdiv lock es mode play2 endif ensoniq mode es mode play2 spin unlock irq ensoniq reg lock',
#  'snd ensoniq capture close snd pcm substream substream ensoniq ensoniq snd pcm substream chip substream ensoniq capture substream null spin lock irq ensoniq reg lock ifdef chip1370 ensoniq es1370 pclkdiv lock es mode capture endif ensoniq mode es mode capture spin unlock irq ensoniq reg lock',
#  'apei hest parse apei hest func func data',
#  'devinit snd ensoniq pcm ensoniq ensoniq device snd pcm rpcm snd pcm pcm err rpcm rpcm null ifdef chip1370 err snd pcm new ensoniq card es1370 device pcm err snd pcm new ensoniq card es1371 device pcm endif err err ifdef chip1370 snd pcm set ops pcm sndrv pcm stream playback snd ensoniq playback2 ops snd pcm set ops pcm sndrv pcm stream playback snd ensoniq playback1 ops endif snd pcm set ops pcm sndrv pcm stream capture snd ensoniq capture ops pcm private data ensoniq pcm info flags ifdef chip1370 strcpy pcm name es1370 dac2 adc strcpy pcm name es1371 dac2 adc endif ensoniq pcm1 pcm snd pcm lib preallocate pages pcm sndrv dma type dev snd dma pci data ensoniq pci rpcm rpcm pcm',
#  'devinit snd ensoniq pcm2 ensoniq ensoniq device snd pcm rpcm snd pcm pcm err rpcm rpcm null ifdef chip1370 err snd pcm new ensoniq card es1370 device pcm err snd pcm new ensoniq card es1371 device pcm endif err err ifdef chip1370 snd pcm set ops pcm sndrv pcm stream playback snd ensoniq playback1 ops snd pcm set ops pcm sndrv pcm stream playback snd ensoniq playback2 ops endif pcm private data ensoniq pcm info flags ifdef chip1370 strcpy pcm name es1370 dac1 strcpy pcm name es1371 dac1 endif ensoniq pcm2 pcm snd pcm lib preallocate pages pcm sndrv dma type dev snd dma pci data ensoniq pci rpcm rpcm pcm',
#  'snd ens1373 spdif info snd kcontrol kcontrol snd ctl elem info uinfo uinfo type sndrv ctl elem type iec958 uinfo count',
#  'snd pcm format check pcm format linear format format check returns given pcm format linear linear negative error code non linear formats snd pcm format snd pcm format format val format format sndrv pcm format last einval val pcm formats format signd einval val',
#  'crypto instance crypto rfc4106 alloc rtattr tb crypto attr type algt crypto instance inst crypto aead spawn spawn crypto alg alg ccm name err algt crypto get attr type tb err ptr err algt err algt err ptr err algt type crypto alg type aead algt mask err ptr einval ccm name crypto attr alg name tb err ptr err ccm name err ccm name err ptr err inst kzalloc inst spawn gfp kernel inst err ptr enomem spawn crypto instance ctx inst crypto set aead spawn spawn inst err crypto grab aead spawn ccm name crypto requires sync algt type algt mask err free inst alg crypto aead spawn alg spawn err einval support byte blocks alg cra aead ivsize drop alg stream cipher alg cra blocksize drop alg err enametoolong snprintf inst alg cra name crypto max alg name rfc4106 alg cra name crypto max alg name snprintf inst alg cra driver name crypto max alg name rfc4106 alg cra driver name crypto max alg name drop alg inst alg cra flags crypto alg type aead inst alg cra flags alg cra flags crypto alg async inst alg cra priority alg cra priority inst alg cra blocksize inst alg cra alignmask alg cra alignmask inst alg cra type crypto nivaead type inst alg cra aead ivsize inst alg cra aead maxauthsize inst alg cra ctxsize crypto rfc4106 ctx inst alg cra init crypto rfc4106 init tfm inst alg cra exit crypto rfc4106 exit tfm inst alg cra aead setkey crypto rfc4106 setkey inst alg cra aead setauthsize crypto rfc4106 setauthsize inst alg cra aead encrypt crypto rfc4106 encrypt inst alg cra aead decrypt crypto rfc4106 decrypt inst alg cra aead geniv seqiv inst drop alg crypto drop aead spawn free inst kfree inst inst err ptr err',
#  'snd ens1373 spdif get snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol spin lock irq ensoniq reg lock ucontrol value iec958 status ensoniq spdif ucontrol value iec958 status ensoniq spdif ucontrol value iec958 status ensoniq spdif ucontrol value iec958 status ensoniq spdif spin unlock irq ensoniq reg lock',
#  'snd ens1373 spdif put snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol val change val u32 ucontrol value iec958 status u32 ucontrol value iec958 status u32 ucontrol value iec958 status u32 ucontrol value iec958 status spin lock irq ensoniq reg lock change ensoniq spdif val ensoniq spdif val change ensoniq playback1 substream null ensoniq playback2 substream null outl val es reg ensoniq channel status spin unlock irq ensoniq reg lock change',
#  'snd ens1373 spdif mask get snd kcontrol kcontrol snd ctl elem value ucontrol ucontrol value iec958 status ucontrol value iec958 status ucontrol value iec958 status ucontrol value iec958 status',
#  'snd ens1373 spdif stream get snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol spin lock irq ensoniq reg lock ucontrol value iec958 status ensoniq spdif stream ucontrol value iec958 status ensoniq spdif stream ucontrol value iec958 status ensoniq spdif stream ucontrol value iec958 status ensoniq spdif stream spin unlock irq ensoniq reg lock',
#  'snd ens1373 spdif stream put snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol val change val u32 ucontrol value iec958 status u32 ucontrol value iec958 status u32 ucontrol value iec958 status u32 ucontrol value iec958 status spin lock irq ensoniq reg lock change ensoniq spdif stream val ensoniq spdif stream val change ensoniq playback1 substream null ensoniq playback2 substream null outl val es reg ensoniq channel status spin unlock irq ensoniq reg lock change',
#  'pci ops pci bus set ops pci bus bus pci ops ops',
#  'snd es1371 spdif get snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol spin lock irq ensoniq reg lock ucontrol value integer value ensoniq ctrl es spdif thru spin unlock irq ensoniq reg lock',
#  'drm vblank init drm device dev num crtcs',
#  'driver support drm drv drm init drm driver driver',
#  'snd pcm format check pcm format linear format format check returns given pcm format linear linear negative error code non linear formats snd pcm format snd pcm format format val val snd pcm format format val val val',
#  'drm exit drm driver driver',
#  'bool drm handle vblank drm device dev crtc',
#  'crypto rfc4106 free crypto instance inst crypto drop spawn crypto instance ctx inst kfree inst',
#  'snd es1371 spdif put snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol nval1 nval2 change nval1 ucontrol value integer value es spdif thru nval2 ucontrol value integer value es spdif en spin lock irq ensoniq reg lock change ensoniq ctrl es spdif thru nval1 ensoniq ctrl es spdif thru ensoniq ctrl nval1 ensoniq cssr es spdif en ensoniq cssr nval2 outl ensoniq ctrl es reg ensoniq control outl ensoniq cssr es reg ensoniq status spin unlock irq ensoniq reg lock change',
#  'snd es1373 rear get snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol val spin lock irq ensoniq reg lock ensoniq cssr es rear bit27 es rear bit26 es rear bit24 es rear bit26 val ucontrol value integer value val spin unlock irq ensoniq reg lock',
#  'snd es1373 rear put snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol nval1 change nval1 ucontrol value integer value es rear bit26 es rear bit27 es rear bit24 spin lock irq ensoniq reg lock change ensoniq cssr es rear bit27 es rear bit26 es rear bit24 nval1 ensoniq cssr es rear bit27 es rear bit26 es rear bit24 ensoniq cssr nval1 outl ensoniq cssr es reg ensoniq status spin unlock irq ensoniq reg lock change',
#  'snd es1373 line get snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol val spin lock irq ensoniq reg lock ensoniq ctrl es gpio outm val ucontrol value integer value val spin unlock irq ensoniq reg lock',
#  'snd es1373 line put snd kcontrol kcontrol snd ctl elem value ucontrol ensoniq ensoniq snd kcontrol chip kcontrol changed ctrl spin lock irq ensoniq reg lock ctrl ensoniq ctrl ucontrol value integer value ensoniq ctrl es gpio line rear ensoniq ctrl es gpio changed ctrl ensoniq ctrl changed outl ensoniq ctrl es reg ensoniq control spin unlock irq ensoniq reg lock changed',
#  'snd ensoniq mixer free ac97 snd ac97 ac97 ensoniq ensoniq ac97 private data ensoniq es1371 ac97 null',
#  'es1371 quirk lookup ensoniq ensoniq es1371 quirk list list vid pci id ensoniq pci vendor list vid ensoniq pci device list ensoniq rev list rev list',
#  'snd pcm format linear check pcm format linear format format check returns given pcm format linear snd pcm format linear snd pcm format format snd pcm format format',
#  'devinit snd ensoniq mixer ensoniq ensoniq spdif line snd card card ensoniq card snd ac97 bus pbus snd ac97 template ac97 err snd ac97 bus ops ops write snd es1371 codec write read snd es1371 codec read wait snd es1371 codec wait err snd ac97 bus card ops null pbus err memset ac97 ac97 ac97 private data ensoniq ac97 private free snd ensoniq mixer free ac97 ac97 pci ensoniq pci ac97 scaps ac97 scap audio err snd ac97 mixer pbus ac97 ensoniq es1371 ac97 err spdif spdif es1371 quirk lookup ensoniq es1371 spdif present snd kcontrol kctl spdif ensoniq spdif ensoniq spdif stream sndrv pcm con spdif outl ensoniq spdif es reg ensoniq channel status ensoniq es1371 ac97 ext id ac97 ei spdif spdif array size snd es1371 mixer spdif kctl snd ctl new1 snd es1371 mixer spdif ensoniq kctl enomem kctl id index spdif err snd ctl add card kctl err err ensoniq es1371 ac97 ext id ac97 ei sdac mirror rear front speakers ensoniq cssr es rear bit27 es rear bit24 ensoniq cssr es rear bit26 err snd ctl add card snd ctl new1 snd ens1373 rear ensoniq err err line snd pci quirk lookup ensoniq pci ens1373 line quirk err snd ctl add card snd ctl new1 snd ens1373 line ensoniq err err',
#  'crypto rfc4543 setkey crypto aead parent u8 key keylen crypto rfc4543 ctx ctx crypto aead ctx parent crypto aead child ctx child err keylen einval keylen memcpy ctx nonce key keylen crypto aead clear flags child crypto tfm req mask crypto aead set flags child crypto aead get flags parent crypto tfm req mask err crypto aead setkey child key keylen crypto aead set flags parent crypto aead get flags child crypto tfm res mask err',
#  'devinit snd ensoniq get joystick port dev joystick port dev disabled detect joystick port dev printk kern err ens1371 invalid joystick port joystick port dev',
#  'devinit snd ensoniq create gameport ensoniq ensoniq dev gameport gp io port io port snd ensoniq get joystick port dev io port enosys detect io port io port io port request region io port ens137x gameport io port printk kern warning ens137x gameport ports available ebusy request region io port ens137x gameport printk kern warning ens137x gameport io port use io port ebusy ensoniq gameport gp gameport allocate port gp printk kern err ens137x cannot allocate memory gameport release region io port enomem gameport set name gp es137x gameport set phys gp pci gameport0 pci name ensoniq pci gameport set dev parent gp ensoniq pci dev gp io io port ensoniq ctrl es jystk en ifdef chip1371 ensoniq ctrl es joy aselm ensoniq ctrl es joy asel io port endif outl ensoniq ctrl es reg ensoniq control gameport port ensoniq gameport',
#  'drm compat ioctl file filp cmd arg',
#  'snd ensoniq free gameport ensoniq ensoniq ensoniq gameport port ensoniq gameport io gameport unregister port ensoniq gameport ensoniq gameport null ensoniq ctrl es jystk en outl ensoniq ctrl es reg ensoniq control release region port',
#  'snd ensoniq proc read snd info entry entry snd info buffer buffer ensoniq ensoniq entry private data ifdef chip1370 snd iprintf buffer ensoniq audiopci es1370 snd iprintf buffer ensoniq audiopci es1371 endif snd iprintf buffer joystick enable ensoniq ctrl es jystk en ifdef chip1370 snd iprintf buffer mic bias ensoniq ctrl es xctl1 snd iprintf buffer line aout ensoniq ctrl es xctl0 snd iprintf buffer joystick port es joy aseli ensoniq ctrl endif',
#  'devinit snd ensoniq proc init ensoniq ensoniq snd info entry entry snd card proc new ensoniq card audiopci entry snd info set text ops entry ensoniq snd ensoniq proc read',
#  'snd ensoniq free ensoniq ensoniq snd ensoniq free gameport ensoniq ensoniq irq hw end ifdef chip1370 outl es serr disable es reg ensoniq control everything outl es reg ensoniq serial clear serial interface outl es reg ensoniq control everything outl es reg ensoniq serial clear serial interface endif ensoniq irq synchronize irq ensoniq irq pci set power state ensoniq pci hw end ifdef chip1370 ensoniq dma bug area snd dma free pages ensoniq dma bug endif ensoniq irq free irq ensoniq irq ensoniq pci release regions ensoniq pci pci disable device ensoniq pci kfree ensoniq',
#  'drm local map drm getsarea drm device dev',
#  'snd pcm format little endian check pcm format little endian format format check returns given pcm format little endian big endian negative error code endian specified snd pcm format little endian snd pcm format format val format format sndrv pcm format last einval val pcm formats format le einval val',
#  'inline drm local map drm core findmap drm device dev token drm map list entry list entry entry dev maplist head entry user token token entry map null',
#  'drm core ioremap wc drm local map map drm device dev',
#  'snd ensoniq dev free snd device device ensoniq ensoniq device device data snd ensoniq free ensoniq',
#  'ati pcigart support ati pcigart drm ati pcigart init drm device dev drm ati pcigart info gart info',
#  'drm core ioremapfree drm local map map drm device dev',
#  'drm ati pcigart cleanup drm device dev drm ati pcigart info gart info',
#  'snd ensoniq chip init ensoniq ensoniq ifdef chip1371 idx endif code part snd ensoniq create intruduction suspend resume ifdef chip1370 outl ensoniq ctrl es reg ensoniq control outl ensoniq sctrl es reg ensoniq serial outl es mem pageo es page adc es reg ensoniq mem page outl ensoniq dma bug addr es reg ensoniq phantom frame outl es reg ensoniq phantom count outl ensoniq ctrl es reg ensoniq control outl ensoniq sctrl es reg ensoniq serial outl es reg ensoniq legacy es1371 quirk lookup ensoniq es1371 ac97 reset hack outl ensoniq cssr es reg ensoniq status need delay around bleech give codecs enough time wakeup msleep ac warm reset start bitclk outl ensoniq ctrl es sync res es reg ensoniq control inl es reg ensoniq control udelay outl ensoniq ctrl es reg ensoniq control init sample rate converter snd es1371 wait src ready ensoniq outl es src disable es reg ensoniq smprate idx idx idx snd es1371 src write ensoniq idx snd es1371 src write ensoniq es smpreg dac1 es smpreg trunc snd es1371 src write ensoniq es smpreg dac1 es smpreg regs snd es1371 src write ensoniq es smpreg dac2 es smpreg trunc snd es1371 src write ensoniq es smpreg dac2 es smpreg regs snd es1371 src write ensoniq es smpreg vol adc snd es1371 src write ensoniq es smpreg vol adc snd es1371 src write ensoniq es smpreg vol dac1 snd es1371 src write ensoniq es smpreg vol dac1 snd es1371 src write ensoniq es smpreg vol dac2 snd es1371 src write ensoniq es smpreg vol dac2 snd es1371 adc rate ensoniq snd es1371 dac1 rate ensoniq snd es1371 dac2 rate ensoniq warning enabling sample rate converter without properly programming parameters causes chip lock src busy bit stuck high found way rectify power cycle thomas sailer snd es1371 wait src ready ensoniq outl es reg ensoniq smprate try reset codec directly outl es codec write es reg ensoniq codec endif outb ensoniq uartc es reg ensoniq uart control outb es reg ensoniq uart res outl ensoniq cssr es reg ensoniq status synchronize irq ensoniq irq',
#  'snd ensoniq suspend pci dev pci pm message state snd card card pci get drvdata pci ensoniq ensoniq card private data snd power change state card sndrv ctl power d3hot snd pcm suspend ensoniq pcm1 snd pcm suspend ensoniq pcm2 ifdef chip1371 snd ac97 suspend ensoniq es1371 ac97 try reset ak4531 outw es codec write ak4531 reset es reg ensoniq codec inw es reg ensoniq codec udelay outw es codec write ak4531 reset es reg ensoniq codec inw es reg ensoniq codec udelay snd ak4531 suspend ensoniq es1370 ak4531 endif pci disable device pci pci save state pci pci set power state pci pci choose state pci state',
#  'snd ensoniq resume pci dev pci snd card card pci get drvdata pci ensoniq ensoniq card private data pci set power state pci pci d0 pci restore state pci pci enable device pci printk kern err driver name pci enable device failed disabling device snd card disconnect card eio pci set master pci snd ensoniq chip init ensoniq ifdef chip1371 snd ac97 resume ensoniq es1371 ac97 snd ak4531 resume ensoniq es1370 ak4531 endif snd power change state card sndrv ctl power d0',
#  'devinit snd ensoniq create snd card card pci dev pci ensoniq rensoniq ensoniq ensoniq err snd device ops ops dev free snd ensoniq dev free rensoniq null err pci enable device pci err ensoniq kzalloc ensoniq gfp kernel ensoniq null pci disable device pci enomem spin lock init ensoniq reg lock mutex init ensoniq src mutex ensoniq card card ensoniq pci pci ensoniq irq err pci request regions pci ensoniq audiopci kfree ensoniq pci disable device pci err ensoniq port pci resource start pci request irq pci irq snd audiopci interrupt irqf shared ensoniq audiopci ensoniq snd printk kern err unable grab irq pci irq snd ensoniq free ensoniq ebusy ensoniq irq pci irq ifdef chip1370 snd dma alloc pages sndrv dma type dev snd dma pci data pci ensoniq dma bug snd printk kern err unable allocate space phantom area dma bug snd ensoniq free ensoniq ebusy endif pci set master pci ensoniq rev pci revision ifdef chip1370 ensoniq ctrl es cdc en es serr disable es pclkdivo es srtodiv get microphone working ensoniq ctrl es cdc en es pclkdivo es srtodiv endif ensoniq sctrl ensoniq ctrl ensoniq sctrl ensoniq cssr snd pci quirk lookup pci es1371 amplifier hack ensoniq ctrl es gpio turn amplifier es1371 quirk lookup ensoniq es1371 ac97 reset hack ensoniq cssr es st ac97 rst endif snd ensoniq chip init ensoniq err snd device new card sndrv dev lowlevel ensoniq ops snd ensoniq free ensoniq err snd ensoniq proc init ensoniq snd card set dev card pci dev rensoniq ensoniq',
#  'inline crypto aead set flags crypto aead tfm u32 flags crypto tfm set flags crypto aead tfm tfm flags',
#  'midi section snd ensoniq midi interrupt ensoniq ensoniq snd rawmidi rmidi ensoniq rmidi status mask byte rmidi null rx first spin lock ensoniq reg lock mask ensoniq uartm es mode input es rxrdy mask status inb es reg ensoniq uart status status mask byte inb es reg ensoniq uart data snd rawmidi receive ensoniq midi input byte spin unlock ensoniq reg lock tx second spin lock ensoniq reg lock mask ensoniq uartm es mode output es txrdy mask status inb es reg ensoniq uart status status mask snd rawmidi transmit ensoniq midi output byte ensoniq uartc es txintenm outb ensoniq uartc es reg ensoniq uart control mask es txrdy outb byte es reg ensoniq uart data spin unlock ensoniq reg lock',
#  'snd ensoniq midi input open snd rawmidi substream substream ensoniq ensoniq substream rmidi private data spin lock irq ensoniq reg lock ensoniq uartm es mode input ensoniq midi input substream ensoniq uartm es mode output outb es cntrl es reg ensoniq uart control outb ensoniq uartc es reg ensoniq uart control outl ensoniq ctrl es uart en es reg ensoniq control spin unlock irq ensoniq reg lock',
#  'snd ensoniq midi input close snd rawmidi substream substream ensoniq ensoniq substream rmidi private data spin lock irq ensoniq reg lock ensoniq uartm es mode output outb ensoniq uartc es reg ensoniq uart control outl ensoniq ctrl es uart en es reg ensoniq control outb ensoniq uartc es rxinten es reg ensoniq uart control ensoniq midi input null ensoniq uartm es mode input spin unlock irq ensoniq reg lock',
#  'snd ensoniq midi output open snd rawmidi substream substream ensoniq ensoniq substream rmidi private data spin lock irq ensoniq reg lock ensoniq uartm es mode output ensoniq midi output substream ensoniq uartm es mode input outb es cntrl es reg ensoniq uart control outb ensoniq uartc es reg ensoniq uart control outl ensoniq ctrl es uart en es reg ensoniq control spin unlock irq ensoniq reg lock',
#  'snd ensoniq midi output close snd rawmidi substream substream ensoniq ensoniq substream rmidi private data spin lock irq ensoniq reg lock ensoniq uartm es mode input outb ensoniq uartc es reg ensoniq uart control outl ensoniq ctrl es uart en es reg ensoniq control outb ensoniq uartc es txintenm es reg ensoniq uart control ensoniq midi output null ensoniq uartm es mode output spin unlock irq ensoniq reg lock',
#  'crypto rfc4543 setauthsize crypto aead parent authsize crypto rfc4543 ctx ctx crypto aead ctx parent authsize einval crypto aead setauthsize ctx child authsize',
#  'snd ensoniq midi input trigger snd rawmidi substream substream flags ensoniq ensoniq substream rmidi private data idx spin lock irqsave ensoniq reg lock flags ensoniq uartc es rxinten empty input fifo idx idx idx inb es reg ensoniq uart data ensoniq uartc es rxinten outb ensoniq uartc es reg ensoniq uart control ensoniq uartc es rxinten ensoniq uartc es rxinten outb ensoniq uartc es reg ensoniq uart control spin unlock irqrestore ensoniq reg lock flags',
#  'snd ensoniq midi output trigger snd rawmidi substream substream flags ensoniq ensoniq substream rmidi private data byte spin lock irqsave ensoniq reg lock flags es txinteni ensoniq uartc ensoniq uartc es txinteno fill uart fifo buffer first turn tx interrupts necessary es txinteni ensoniq uartc inb es reg ensoniq uart status es txrdy snd rawmidi transmit substream byte ensoniq uartc es txintenm outb byte es reg ensoniq uart data outb ensoniq uartc es reg ensoniq uart control es txinteni ensoniq uartc ensoniq uartc es txintenm outb ensoniq uartc es reg ensoniq uart control spin unlock irqrestore ensoniq reg lock flags',
#  'devinit snd ensoniq midi ensoniq ensoniq device snd rawmidi rrawmidi snd rawmidi rmidi err rrawmidi rrawmidi null err snd rawmidi new ensoniq card es1370 device rmidi err ifdef chip1370 strcpy rmidi name es1370 strcpy rmidi name es1371 endif snd rawmidi set ops rmidi sndrv rawmidi stream output snd ensoniq midi output snd rawmidi set ops rmidi sndrv rawmidi stream input snd ensoniq midi input rmidi info flags sndrv rawmidi info output sndrv rawmidi info input sndrv rawmidi info duplex rmidi private data ensoniq ensoniq rmidi rmidi rrawmidi rrawmidi rmidi',
#  'drm core ioremap drm local map map drm device dev',
#  'snd pcm format big endian check pcm format big endian format format check returns given pcm format big endian little endian negative error code endian specified snd pcm format big endian snd pcm format format val val snd pcm format little endian format val val val',
#  'interrupt handler irqreturn snd audiopci interrupt irq dev id ensoniq ensoniq dev id status sctrl ensoniq null irq none status inl es reg ensoniq status status es intr irq none spin lock ensoniq reg lock sctrl ensoniq sctrl status es dac1 sctrl es p1 en status es dac2 sctrl es p2 en status es adc sctrl es r1 en outl sctrl es reg ensoniq serial outl ensoniq sctrl es reg ensoniq serial spin unlock ensoniq reg lock status es uart snd ensoniq midi interrupt ensoniq status es dac2 ensoniq playback2 substream snd pcm period elapsed ensoniq playback2 substream status es adc ensoniq capture substream snd pcm period elapsed ensoniq capture substream status es dac1 ensoniq playback1 substream snd pcm period elapsed ensoniq playback1 substream irq handled',
#  'devinit snd audiopci probe pci dev pci pci device id pci id dev snd card card ensoniq ensoniq err pcm devs dev sndrv cards enodev enable dev dev enoent err snd card create index dev id dev module card err err err snd ensoniq create card pci ensoniq snd card free card err card private data ensoniq pcm devs pcm devs ifdef chip1370 err snd ensoniq mixer ensoniq snd card free card err endif ifdef chip1371 err snd ensoniq mixer ensoniq spdif dev lineio dev snd card free card err endif err snd ensoniq pcm ensoniq null snd card free card err err snd ensoniq pcm2 ensoniq null snd card free card err err snd ensoniq midi ensoniq null snd card free card err snd ensoniq create gameport ensoniq dev strcpy card driver driver name strcpy card shortname ensoniq audiopci sprintf card longname lx irq card shortname card driver ensoniq port ensoniq irq err snd card card snd card free card err pci set drvdata pci card dev',
#  'devexit snd audiopci remove pci dev pci snd card free pci get drvdata pci pci set drvdata pci null',
#  'init alsa card ens137x init pci driver driver',
#  'exit alsa card ens137x exit pci unregister driver driver',
#  'aead request crypto rfc4543 crypt aead request req enc crypto aead aead crypto aead reqtfm req crypto rfc4543 ctx ctx crypto aead ctx aead crypto rfc4543 req ctx rctx crypto rfc4543 reqctx req aead request subreq rctx subreq scatterlist dst req dst scatterlist cipher rctx cipher scatterlist payload rctx payload scatterlist assoc rctx assoc authsize crypto aead authsize aead assoclen req assoclen page dstp u8 vdst u8 iv ptr align u8 rctx crypto aead reqsize ctx child crypto aead alignmask ctx child memcpy iv ctx nonce memcpy iv req iv construct cipher plaintext enc memset rctx auth tag authsize scatterwalk map copy rctx auth tag dst req cryptlen authsize authsize sg init one cipher rctx auth tag authsize construct aad dstp sg page dst vdst pagehighmem dstp null page address dstp dst offset sg init table payload sg set buf payload req iv scatterwalk crypto chain payload dst vdst req iv assoclen req cryptlen enc authsize sg init table assoc sg set page assoc sg page req assoc req assoc length req assoc offset scatterwalk crypto chain assoc payload aead request set tfm subreq ctx child aead request set callback subreq req base flags req base complete req base data aead request set crypt subreq cipher cipher enc authsize iv aead request set assoc subreq assoc assoclen subreq',
#  'drm agp acquire drm device dev',
#  'drm agp info drm device dev drm agp info info',
#  'drm agp enable drm device dev drm agp mode mode',
#  'drm agp alloc drm device dev drm agp buffer request',
#  'snd pcm format width bit width format format format check returns bit width format negative error code unknown format snd pcm format width snd pcm format format val format format sndrv pcm format last einval val pcm formats format width einval val',
#  'drm agp bind drm device dev drm agp binding request',
#  'drm addmap drm device dev resource size offset size drm map type type drm map flags flags drm local map map ptr',
#  'buffer management support drm bufs drm addbufs agp drm device dev drm buf desc request',
#  'drm addbufs pci drm device dev drm buf desc request',
#  'drm agp unbind drm device dev drm agp binding request',
#  'drm agp free drm device dev drm agp buffer request',
#  'snd azf3328 io reg setb reg u8 mask bool set well strictly spoken inb outb sequence atomic would need locking however currently care since potentially complicates matters u8 prev inb reg new new set prev mask prev mask need always write new value matter whether differs since bits indicate setting outb new reg new prev',
#  'crypto rfc4543 encrypt aead request req crypto aead aead crypto aead reqtfm req crypto rfc4543 req ctx rctx crypto rfc4543 reqctx req aead request subreq err subreq crypto rfc4543 crypt req err crypto aead encrypt subreq err err scatterwalk map copy rctx auth tag req dst req cryptlen crypto aead authsize aead',
#  'snd azf3328 mixer set mute snd azf3328 chip reg bool mute portbase chip mixer io reg bool updated mute bit second right left right channel setting updated snd azf3328 io reg setb portbase azf mute bit mute indicate whether muted mute updated updated',
#  'crypto rfc4543 decrypt aead request req req crypto rfc4543 crypt req crypto aead decrypt req',
#  'snd pcm format physical width physical bit width format format format check returns physical bit width format negative error code unknown format snd pcm format physical width snd pcm format format val format format sndrv pcm format last einval val pcm formats format phys einval val',
#  'snd azf3328 mixer write volume gradually snd azf3328 chip reg dst vol left dst vol right chan sel delay portbase chip mixer io reg curr vol left curr vol right left change right change snd azf3328 dbgcallenter chan sel set chan left curr vol left inb portbase take care muting flag contained left channel curr vol left azf mute bit dst vol left azf mute bit dst vol left azf mute bit left change curr vol left dst vol left chan sel set chan right curr vol right inb portbase right change curr vol right dst vol right left change curr vol left dst vol left curr vol left left change outb curr vol left portbase left change right change curr vol right dst vol right curr vol right right change volume change right channel crackling somewhat left channel unfortunately seems hardware issue outb curr vol right portbase right change delay mdelay delay left change right change snd azf3328 dbgcallleave',
#  'crypto rfc4543 init tfm crypto tfm tfm crypto instance inst tfm crt alg crypto aead spawn spawn crypto instance ctx inst crypto rfc4543 ctx ctx crypto tfm ctx tfm crypto aead aead align aead crypto spawn aead spawn err aead ptr err aead ctx child aead align crypto aead alignmask aead align crypto tfm ctx alignment tfm crt aead reqsize crypto rfc4543 req ctx align crypto aead reqsize aead crypto tfm ctx alignment align',
#  'snd azf3328 mixer reg decode azf3328 mixer reg val reg val lchan shift val rchan shift val mask val invert val stereo val val',
#  'snd azf3328 info mixer snd kcontrol kcontrol snd ctl elem info uinfo azf3328 mixer reg reg snd azf3328 dbgcallenter snd azf3328 mixer reg decode reg kcontrol private value uinfo type reg mask sndrv ctl elem type boolean sndrv ctl elem type integer uinfo count reg stereo uinfo value integer min uinfo value integer max reg mask snd azf3328 dbgcallleave',
#  'snd azf3328 get mixer snd kcontrol kcontrol snd ctl elem value ucontrol snd azf3328 chip snd kcontrol chip kcontrol azf3328 mixer reg reg u16 oreg val snd azf3328 dbgcallenter snd azf3328 mixer reg decode reg kcontrol private value oreg snd azf3328 mixer inw chip reg reg val oreg reg lchan shift reg mask reg invert val reg mask val ucontrol value integer value val reg stereo val oreg reg rchan shift reg mask reg invert val reg mask val ucontrol value integer value val snd azf3328 dbgmixer get vol shift mask inv stereo reg reg oreg ucontrol value integer value ucontrol value integer value reg lchan shift reg rchan shift reg mask reg invert reg stereo snd azf3328 dbgcallleave',
#  'snd azf3328 put mixer snd kcontrol kcontrol snd ctl elem value ucontrol snd azf3328 chip snd kcontrol chip kcontrol azf3328 mixer reg reg u16 oreg nreg val snd azf3328 dbgcallenter snd azf3328 mixer reg decode reg kcontrol private value oreg snd azf3328 mixer inw chip reg reg val ucontrol value integer value reg mask reg invert val reg mask val nreg oreg reg mask reg lchan shift nreg val reg lchan shift reg stereo val ucontrol value integer value reg mask reg invert val reg mask val nreg reg mask reg rchan shift nreg val reg rchan shift reg mask volume control better take care snd azf3328 mixer write volume gradually chip reg reg nreg nreg set channels matter set chan left set chan right snd azf3328 mixer outw chip reg reg nreg snd azf3328 dbgmixer put oreg shift nreg reg reg ucontrol value integer value ucontrol value integer value oreg reg lchan shift reg rchan shift nreg snd azf3328 mixer inw chip reg reg snd azf3328 dbgcallleave nreg oreg',
#  'crypto rfc4543 exit tfm crypto tfm tfm crypto rfc4543 ctx ctx crypto tfm ctx tfm crypto free aead ctx child',
#  'snd azf3328 info mixer snd kcontrol kcontrol snd ctl elem info uinfo texts1 mic1 mic2 texts2 mix mic texts3 mic cd video aux line mix mix mono phone texts4 pre post azf3328 mixer reg reg null snd azf3328 mixer reg decode reg kcontrol private value uinfo type sndrv ctl elem type enumerated uinfo count reg reg idx mixer rec select uinfo value enumerated items reg uinfo value enumerated item reg uinfo value enumerated item reg reg reg idx mixer advctl2 reg lchan shift modem sel texts1 mono sel source texts2 pcm path texts4 reg reg idx mixer rec select texts3 strcpy uinfo value enumerated name uinfo value enumerated item',
#  'snd azf3328 get mixer snd kcontrol kcontrol snd ctl elem value ucontrol snd azf3328 chip snd kcontrol chip kcontrol azf3328 mixer reg reg val snd azf3328 mixer reg decode reg kcontrol private value val snd azf3328 mixer inw chip reg reg reg reg idx mixer rec select ucontrol value enumerated item val reg ucontrol value enumerated item val reg ucontrol value enumerated item val reg lchan shift reg snd azf3328 dbgmixer get shift reg reg val ucontrol value enumerated item ucontrol value enumerated item reg lchan shift reg',
#  'snd azf3328 put mixer snd kcontrol kcontrol snd ctl elem value ucontrol snd azf3328 chip snd kcontrol chip kcontrol azf3328 mixer reg reg u16 oreg nreg val snd azf3328 mixer reg decode reg kcontrol private value oreg snd azf3328 mixer inw chip reg reg val oreg reg reg idx mixer rec select ucontrol value enumerated item reg ucontrol value enumerated item reg einval val ucontrol value enumerated item ucontrol value enumerated item ucontrol value enumerated item reg einval val reg reg lchan shift val ucontrol value enumerated item reg lchan shift snd azf3328 mixer outw chip reg reg val nreg val snd azf3328 dbgmixer put oreg reg reg val oreg nreg oreg',
#  'snd rawmidi ioctl compat file file cmd arg snd rawmidi file rfile user argp compat ptr arg rfile file private data cmd sndrv rawmidi ioctl pversion sndrv rawmidi ioctl info sndrv rawmidi ioctl drop sndrv rawmidi ioctl drain snd rawmidi ioctl file cmd argp sndrv rawmidi ioctl params32 snd rawmidi ioctl params compat rfile argp sndrv rawmidi ioctl status32 snd rawmidi ioctl status compat rfile argp enoioctlcmd',
#  'snd pcm format size byte size samples given format format format check samples sampling rate returns byte size given samples format negative error code unknown format ssize snd pcm format size snd pcm format format size samples phys width snd pcm format physical width format phys width einval samples phys width',
#  'snd azf3328 mixer new snd azf3328 chip snd card card snd kcontrol new sw idx err snd azf3328 dbgcallenter snd bug chip chip card einval card chip card mixer reset snd azf3328 mixer outw chip idx mixer reset mute zero volume channels idx idx array size snd azf3328 init values idx snd azf3328 mixer outw chip snd azf3328 init values idx snd azf3328 init values idx add mixer controls sw snd azf3328 mixer controls idx idx array size snd azf3328 mixer controls idx sw err snd ctl add chip card snd ctl new1 sw chip err snd component add card azf3328 mixer strcpy card mixername azf3328 mixer snd azf3328 dbgcallleave',
#  'snd azf3328 hw params snd pcm substream substream snd pcm hw params hw params res snd azf3328 dbgcallenter res snd pcm lib malloc pages substream params buffer bytes hw params snd azf3328 dbgcallleave res',
#  'snd azf3328 hw free snd pcm substream substream snd azf3328 dbgcallenter snd pcm lib free pages substream snd azf3328 dbgcallleave',
#  'crypto instance crypto rfc4543 alloc rtattr tb crypto attr type algt crypto instance inst crypto aead spawn spawn crypto alg alg ccm name err algt crypto get attr type tb err ptr err algt err algt err ptr err algt type crypto alg type aead algt mask err ptr einval ccm name crypto attr alg name tb err ptr err ccm name err ccm name err ptr err inst kzalloc inst spawn gfp kernel inst err ptr enomem spawn crypto instance ctx inst crypto set aead spawn spawn inst err crypto grab aead spawn ccm name crypto requires sync algt type algt mask err free inst alg crypto aead spawn alg spawn err einval support byte blocks alg cra aead ivsize drop alg stream cipher alg cra blocksize drop alg err enametoolong snprintf inst alg cra name crypto max alg name rfc4543 alg cra name crypto max alg name snprintf inst alg cra driver name crypto max alg name rfc4543 alg cra driver name crypto max alg name drop alg inst alg cra flags crypto alg type aead inst alg cra flags alg cra flags crypto alg async inst alg cra priority alg cra priority inst alg cra blocksize inst alg cra alignmask alg cra alignmask inst alg cra type crypto nivaead type inst alg cra aead ivsize inst alg cra aead maxauthsize inst alg cra ctxsize crypto rfc4543 ctx inst alg cra init crypto rfc4543 init tfm inst alg cra exit crypto rfc4543 exit tfm inst alg cra aead setkey crypto rfc4543 setkey inst alg cra aead setauthsize crypto rfc4543 setauthsize inst alg cra aead encrypt crypto rfc4543 encrypt inst alg cra aead decrypt crypto rfc4543 decrypt inst alg cra aead geniv seqiv inst drop alg crypto drop aead spawn free inst kfree inst inst err ptr err',
#  'snd azf3328 codec setfmt snd azf3328 codec data codec azf freq bitrate format width channels flags u16 val u8 freq snd azf3328 dbgcallenter bitrate azf freq freq soundformat freq suspected azf freq freq soundformat freq suspected azf freq azf3328 names strange reason freq soundformat freq azf freq freq soundformat freq azf freq freq soundformat freq azf freq freq soundformat freq azf freq freq soundformat freq azf freq freq soundformat freq suspected azf freq freq soundformat freq azf freq freq soundformat freq azf freq freq soundformat freq snd printk kern warning unknown bitrate assuming bitrate fall azf freq freq soundformat freq azf freq freq soundformat freq azf freq freq soundformat freq suspected val hmm val hmm val yup val yup val val val val val val freq channels val soundformat flag format width val soundformat flag spin lock irqsave codec lock flags set bitrate format snd azf3328 codec outw codec idx io codec soundformat val changing bitrate format settings switches audio output annoying click format change maybe shutting dac adc thus immediately tweaking reenable get rid clicking fixme yes works exactly fixme side effects full duplex dramatic side effects non capture codecs codec type azf codec capture snd azf3328 codec outw codec idx io codec dma flags snd azf3328 codec inw codec idx io codec dma flags dma run something1 dma run something2 something almost always set dma epilogue something dma something spin unlock irqrestore codec lock flags snd azf3328 dbgcallleave',
#  'crypto rfc4543 free crypto instance inst crypto drop spawn crypto instance ctx inst kfree inst',
#  'snd azf3328 ctrl reg update snd azf3328 chip bitmask bool enable bool mask enable mask chip shadow reg ctrl bitmask chip shadow reg ctrl bitmask snd azf3328 dbgcodec update mask mask val bitmask mask chip shadow reg ctrl snd azf3328 ctrl outw chip idx io chip shadow reg ctrl',
#  'snd azf3328 ctrl codec activity snd azf3328 chip snd azf3328 codec type codec type bool enable snd azf3328 codec data codec chip codecs codec type bool need change codec running enable snd azf3328 dbgcodec codec activity codec enable need change codec name enable need change need change snd azf3328 codec type other1 snd azf3328 codec type other2 peer codecs azf codec capture azf codec i2s azf codec playback azf codec i2s azf codec playback azf codec capture bool call function enable enable codec call enable codecs func enable codec supply call function otherwise call enable codecs func globally shuts operation codecs codecs currently active either call function chip codecs peer codecs codec type other1 running chip codecs peer codecs codec type other2 running call function snd azf3328 ctrl enable codecs chip enable adjust clock reduce noise power consumption enable snd azf3328 codec setfmt lowpower codec codec running enable',
# ...
#  'snd bt87x capture volume info snd kcontrol kcontrol snd ctl elem info info info type sndrv ctl elem type integer info count info value integer min info value integer max',
#  'snd bt87x capture volume get snd kcontrol kcontrol snd ctl elem value value snd bt87x chip snd kcontrol chip kcontrol value value integer value chip reg control ctl gain mask ctl gain shift',
#  'snd bt87x capture volume put snd kcontrol kcontrol snd ctl elem value value snd bt87x chip snd kcontrol chip kcontrol u32 old control changed spin lock irq chip reg lock old control chip reg control chip reg control chip reg control ctl gain mask value value integer value ctl gain shift snd bt87x writel chip reg gpio dma ctl chip reg control changed old control chip reg control spin unlock irq chip reg lock changed',
#  'snd bt87x capture boost get snd kcontrol kcontrol snd ctl elem value value snd bt87x chip snd kcontrol chip kcontrol value value integer value chip reg control ctl g2x',
#  'inline crypto aead aead givcrypt reqtfm aead givcrypt request req crypto aead reqtfm req areq',
#  'snd bt87x capture boost put snd kcontrol kcontrol snd ctl elem value value snd bt87x chip snd kcontrol chip kcontrol u32 old control changed spin lock irq chip reg lock old control chip reg control chip reg control chip reg control ctl g2x value value integer value ctl g2x snd bt87x writel chip reg gpio dma ctl chip reg control changed chip reg control old control spin unlock irq chip reg lock changed',
#  'snd bt87x capture source info snd kcontrol kcontrol snd ctl elem info info texts tv tuner fm mic line snd ctl info info texts',
#  'init deflate mod init crypto alg alg',
#  'snd bt87x capture source get snd kcontrol kcontrol snd ctl elem value value snd bt87x chip snd kcontrol chip kcontrol value value enumerated item chip reg control ctl sel mask ctl sel shift',
#  'snd bt87x capture source put snd kcontrol kcontrol snd ctl elem value value snd bt87x chip snd kcontrol chip kcontrol u32 old control changed spin lock irq chip reg lock old control chip reg control chip reg control chip reg control ctl sel mask value value enumerated item ctl sel shift snd bt87x writel chip reg gpio dma ctl chip reg control changed chip reg control old control spin unlock irq chip reg lock changed',
#  'snd bt87x free snd bt87x chip chip mmio snd bt87x stop chip chip irq free irq chip irq chip chip mmio iounmap chip mmio pci release regions chip pci pci disable device chip pci kfree chip',
#  'exit deflate mod fini crypto unregister alg alg',
#  'snd bt87x dev free snd device device snd bt87x chip device device data snd bt87x free chip',
#  'devinit snd bt87x pcm snd bt87x chip device name err snd pcm pcm err snd pcm new chip card name device pcm err err pcm private data chip strcpy pcm name name snd pcm set ops pcm sndrv pcm stream capture snd bt87x pcm ops snd pcm lib preallocate pages pcm sndrv dma type dev sg snd dma pci data chip pci align',
#  'devinit snd bt87x create snd card card pci dev pci snd bt87x rchip snd bt87x chip err snd device ops ops dev free snd bt87x dev free rchip null err pci enable device pci err err chip kzalloc chip gfp kernel chip pci disable device pci enomem chip card card chip pci pci chip irq spin lock init chip reg lock err pci request regions pci bt87x audio kfree chip pci disable device pci err chip mmio pci ioremap bar pci chip mmio snd printk kern err cannot remap io memory err enomem fail chip reg control ctl pwrdn ctl da es2 ctl pktp ctl da sdr shift chip interrupt mask interrupts snd bt87x writel chip reg gpio dma ctl chip reg control snd bt87x writel chip reg mask snd bt87x writel chip reg stat interrupts err request irq pci irq snd bt87x interrupt irqf shared bt87x audio chip err snd printk kern err cannot grab irq pci irq fail chip irq pci irq pci set master pci synchronize irq chip irq err snd device new card sndrv dev lowlevel chip ops err fail snd card set dev card pci dev rchip chip fail snd bt87x free chip err',
#  'try allocate large pages possible stores resultant memory size res size minimum size snd minimum buffer power preallocate pcm pages snd pcm substream substream size size snd dma buffer dmab substream dma buffer err already reserved snd dma get reserved buf dmab substream dma buf id dmab bytes size yes free reserved block snd dma free pages dmab dmab bytes err snd dma alloc pages dmab dev type dmab dev dev size dmab err enomem err fatal error size size snd minimum buffer dmab bytes tell error',
#  'id card negative value blacklisted devinit snd bt87x detect card pci dev pci pci device id supported supported pci match id snd bt87x ids pci supported supported driver data supported driver data array size blacklist blacklist subvendor pci subsystem vendor blacklist subdevice pci subsystem device snd printdd kern info card audio pci device pci subsystem vendor pci subsystem device ebusy snd printk kern info unknown card pci device pci subsystem vendor pci subsystem device snd printk kern debug please mail id board name works correct digital rate option alsa devel alsa project org snd bt87x board unknown',
#  'devinit snd bt87x probe pci dev pci pci device id pci id dev snd card card snd bt87x chip err snd bt87x boardid boardid pci id driver data err snd bt87x detect card pci err enodev boardid err boardid pci id driver data dev sndrv cards enodev enable dev dev enoent err snd card create index dev id dev module card err err err snd bt87x create card pci chip err error memcpy chip board snd bt87x boards boardid chip board chip board digital digital rate dev chip board dig rate digital rate dev chip reg control chip board digital fmt err snd bt87x pcm chip device digital bt87x digital err error chip board analog err snd bt87x pcm chip device analog bt87x analog err error err snd ctl add card snd ctl new1 snd bt87x capture volume chip err error err snd ctl add card snd ctl new1 snd bt87x capture boost chip err error err snd ctl add card snd ctl new1 snd bt87x capture source chip err error snd printk kern info bt87x using board sanalog sdigital rate hz dev boardid chip board analog chip board digital chip board dig rate strcpy card driver bt87x sprintf card shortname brooktree bt pci device sprintf card longname llx irq card shortname pci resource start pci chip irq strcpy card mixername bt87x err snd card card err error pci set drvdata pci card dev error snd card free card err',
#  'devexit snd bt87x remove pci dev pci snd card free pci get drvdata pci pci set drvdata pci null',
#  'init alsa card bt87x init load driver id table snd bt87x ids pci driver driver',
#  'exit alsa card bt87x exit pci unregister driver driver',
#  'ieee80211 disable dyn ps force mac80211 temporarily disable dynamic psm vif ieee80211 vif pointer add interface callback hardware require full power save manage simultaneous bt traffic wlan frequency full psm required periodically whenever burst bt traffic hardware gets information bt traffic via hardware co existence lines consequentially requests mac80211 temporarily enter full psm function temporarily disable dynamic ps enable psm already enabled driver must make sure enable dynamic ps using ieee80211 enable dyn ps driver disabled ieee80211 disable dyn ps ieee80211 vif vif',
#  'ieee80211 enable dyn ps restore dynamic psm disabled vif ieee80211 vif pointer add interface callback function restores dynamic ps temporarily disabled via ieee80211 disable dyn ps ieee80211 disable dyn ps call must coupled eventual call function ieee80211 enable dyn ps ieee80211 vif vif',
#  'ieee80211 connection loss inform hardware lost connection ap vif ieee80211 vif pointer add interface callback beacon filtering enabled ieee80211 hw beacon filter ieee80211 conf ps ieee80211 hw connection monitor set driver needs inform connection ap lost function cause immediate change disassociated state without connection recovery attempts ieee80211 connection loss ieee80211 vif vif',
#  'module param load bool',
#  'inline u32 snd bt87x readl snd bt87x chip u32 reg readl chip mmio reg',
#  'release preallocated buffer yet done snd pcm lib preallocate dma free snd pcm substream substream substream dma buffer area null substream dma buf id snd dma reserve buf substream dma buffer substream dma buf id snd dma free pages substream dma buffer substream dma buffer area null',
#  'inline snd bt87x writel snd bt87x chip u32 reg u32 value writel value chip mmio reg',
#  'pci device id pci match id pci device id ids pci dev dev',
#  'crypto xcbc digest setkey crypto shash parent u8 inkey keylen alignmask crypto shash alignmask parent xcbc tfm ctx ctx crypto shash ctx parent bs crypto shash blocksize parent u8 consts ptr align ctx ctx alignmask err u8 key1 bs err crypto cipher setkey ctx child inkey keylen err crypto cipher encrypt one ctx child consts u8 ks bs crypto cipher encrypt one ctx child consts bs u8 ks bs crypto cipher encrypt one ctx child key1 u8 ks crypto cipher setkey ctx child key1 bs',
#  'sdio f0 readb sdio func func addr err ret',
#  'sdio f0 writeb sdio func func addr err ret',
#  'ieee80211 ap probereq get retrieve probe request template hw pointer obtained ieee80211 alloc hw vif ieee80211 vif pointer add interface callback creates probe request template example uploaded hardware template filled bssid ssid supported rate information function must called within bss info changed callback function managed mode function useful interface associated otherwise null sk buff ieee80211 ap probereq get ieee80211 hw hw ieee80211 vif vif',
#  'crypto xcbc digest init shash desc pdesc alignmask crypto shash alignmask pdesc tfm xcbc desc ctx ctx shash desc ctx pdesc bs crypto shash blocksize pdesc tfm u8 prev ptr align ctx ctx alignmask bs ctx len memset prev bs',
#  'crypto xcbc digest update shash desc pdesc u8 len crypto shash parent pdesc tfm alignmask crypto shash alignmask parent xcbc tfm ctx tctx crypto shash ctx parent xcbc desc ctx ctx shash desc ctx pdesc crypto cipher tfm tctx child bs crypto shash blocksize parent u8 odds ptr align ctx ctx alignmask u8 prev odds bs checking data fill block ctx len len bs memcpy odds ctx len len ctx len len filling odds new data encrypting memcpy odds ctx len bs ctx len len bs ctx len bs ctx len crypto xor prev odds bs crypto cipher encrypt one tfm prev prev clearing length ctx len encrypting rest data len bs crypto xor prev bs crypto cipher encrypt one tfm prev prev bs len bs keeping surplus blocksize len memcpy odds len ctx len len',
#  'access ac97 codec via normal ich sis7012 snd intel8x0 codec semaphore intel8x0 chip codec time codec eio chip sdin init know ready bit assignment moment check codec chip codec isr bits codec chip codec bit chip ac97 sdin codec codec ready igetdword chip ichreg glob sta codec eio chip buggy semaphore ignore anyone holding semaphore msec shot time igetbyte chip ichreg acc sema ich cas udelay time access forbidden non existant ac97 registers reset semaphore even get semaphore still access need semaphore anyway snd printk kern err codec semaphore semaphore ready igetbyte chip ichreg acc sema igetdword chip ichreg glob sta iagetword chip clear semaphore flag care semaphore ebusy',
#  'snd intel8x0 codec write snd ac97 ac97 reg val intel8x0 chip ac97 private data snd intel8x0 codec semaphore chip ac97 num chip ac97 init snd printk kern err codec write semaphore ready ac97 num reg iaputword chip reg ac97 num val',
#  'videobuf sg alloc size size',
#  'snd intel8x0 codec read snd ac97 ac97 reg intel8x0 chip ac97 private data res tmp snd intel8x0 codec semaphore chip ac97 num chip ac97 init snd printk kern err codec read semaphore ready ac97 num reg res res iagetword chip reg ac97 num tmp igetdword chip ichreg glob sta ich rcs reset rcs preserve wc bits iputdword chip ichreg glob sta tmp chip codec ready bits ich gsci chip ac97 init snd printk kern err codec read read timeout ac97 num reg res res',
#  'crypto xcbc digest final shash desc pdesc u8 crypto shash parent pdesc tfm alignmask crypto shash alignmask parent xcbc tfm ctx tctx crypto shash ctx parent xcbc desc ctx ctx shash desc ctx pdesc crypto cipher tfm tctx child bs crypto shash blocksize parent u8 consts ptr align tctx ctx alignmask u8 odds ptr align ctx ctx alignmask u8 prev odds bs offset ctx len bs rlen u8 odds ctx len rlen bs ctx len rlen memset rlen offset bs crypto xor prev odds bs crypto xor prev consts offset bs crypto cipher encrypt one tfm prev',
#  'devinit snd intel8x0 codec read test intel8x0 chip codec tmp snd intel8x0 codec semaphore chip codec iagetword chip codec tmp igetdword chip ichreg glob sta ich rcs reset rcs preserve wc bits iputdword chip ichreg glob sta tmp chip codec ready bits ich gsci',
#  'access ac97 ali5455 snd intel8x0 ali codec ready intel8x0 chip mask count count count count val igetbyte chip ichreg ali cspsr val mask chip ac97 init snd printd kern warning intel8x0 ac97 codec ready timeout ebusy',
#  'snd intel8x0 ali codec semaphore intel8x0 chip time chip buggy semaphore ignore time igetdword chip ichreg ali cas ali cas sem busy udelay time chip ac97 init snd printk kern warning ali codec semaphore timeout snd intel8x0 ali codec ready chip ali cspsr codec ready',
#  'snd intel8x0 ali codec read snd ac97 ac97 reg intel8x0 chip ac97 private data data snd intel8x0 ali codec semaphore chip err reg ali cpr addr read ac97 num reg ali cpr addr secondary iputword chip ichreg ali cpr addr reg snd intel8x0 ali codec ready chip ali cspsr read ok err data igetword chip ichreg ali spr err data',
#  'snd intel8x0 ali codec write snd ac97 ac97 reg val intel8x0 chip ac97 private data snd intel8x0 ali codec semaphore chip iputword chip ichreg ali cpr val ac97 num reg ali cpr addr secondary iputword chip ichreg ali cpr addr reg snd intel8x0 ali codec ready chip ali cspsr write ok',
#  'dma snd intel8x0 setup periods intel8x0 chip ichdev ichdev idx u32 bdbar ichdev bdbar port ichdev reg offset iputdword chip port ich reg bdbar ichdev bdbar addr ichdev size ichdev fragsize ichdev ack reload ichdev ack ichdev fragsize1 ichdev fragsize idx idx ich reg lvi mask idx bdbar idx cpu le32 ichdev physbuf bdbar idx cpu le32 interrupt completion ichdev fragsize1 ichdev pos shift bdbar idx cpu le32 ichdev physbuf ichdev size bdbar idx cpu le32 interrupt completion ichdev fragsize1 ichdev pos shift ichdev frags ichdev ack reload ichdev ack ichdev fragsize1 ichdev fragsize idx idx ich reg lvi mask idx bdbar idx cpu le32 ichdev physbuf idx ichdev fragsize ichdev size bdbar idx cpu le32 interrupt completion ichdev fragsize ichdev pos shift printk kern debug bdbar idx bdbar idx bdbar idx endif ichdev frags ichdev size ichdev fragsize iputbyte chip port ich reg lvi ichdev lvi ich reg lvi mask ichdev civ iputbyte chip port ich reg civ ichdev lvi frag ich reg lvi mask ichdev frags ichdev position printk kern debug lvi frag frags period size period size1 ichdev lvi frag ichdev frags ichdev fragsize ichdev fragsize1 endif clear interrupts iputbyte chip port ichdev roff sr ich fifoe ich bcis ich lvbci',
#  'irqreturn snd intel8x0 interrupt irq dev id intel8x0 chip dev id ichdev ichdev status status igetdword chip chip sta reg status yet resumed irq none status chip sta mask status ack iputdword chip chip sta reg status chip buggy irq status irq retval status chip bdbars count ichdev chip ichd status ichdev sta mask snd intel8x0 update chip ichdev ack iputdword chip chip sta reg status chip sta mask irq handled',
#  'pcm part snd intel8x0 pcm trigger snd pcm substream substream cmd intel8x0 chip snd pcm substream chip substream ichdev ichdev get ichdev substream val port ichdev reg offset cmd sndrv pcm trigger resume ichdev suspended fallthru sndrv pcm trigger start sndrv pcm trigger pause release val ich ioce ich startbm ichdev last pos ichdev position sndrv pcm trigger suspend ichdev suspended fallthru sndrv pcm trigger stop val sndrv pcm trigger pause push val ich ioce einval iputbyte chip port ich reg cr val cmd sndrv pcm trigger stop wait dma stopped igetbyte chip port ichdev roff sr ich dch reset whole dma things iputbyte chip port ich reg cr ich resetregs',
#  ...]

# %% [markdown]
# Compute IDF and TF-IDF

# %%
# Compute TF-IDF matrix
tvec = TfidfVectorizer(min_df=2)
tvec_weights = tvec.fit_transform(data)
b2 = tvec.get_feature_names()
# TF-IDF Matrix
tfidf = tvec_weights.toarray()
# IDF Dictionary {term: idf}
idfLst = {term: idf for term, idf in zip(tvec.get_feature_names(), tvec.idf_)}

# %% [markdown]
# ## Part II: TF-IDF

# %% [markdown]
# Query Preprocessing

# %%
files = glob(".\IS706\queries\*.txt")
queries = []
for file in files:
    with open(file) as doc:
        content = doc.read().lower().strip()
        for symbol in sym:
            content = content.replace(symbol, " ")
        content =" ".join([i for i in content.replace("\n", " ").replace("\\n", " ").replace("\t", " ").split(" ") if i != "" and i not in keyword and len(i)>1])
    queries.append(content)
queries
# Out:
# ['task delay acct enable per task delay accounting experimental collect information time spent task waiting system resources like cpu synchronous block completion swapping pages statistics help setting task priorities relative tasks cpu io rss limits etc say unsure',
#  'blk cgroup block io controller generic block io controller cgroup interface common cgroup interface used various io controlling policies currently cfq io scheduler uses recognize task groups control disk bandwidth allocation proportional time slice allocation task groups also used bio throttling logic block layer implement upper limit io rates device option enables generic block io controller infrastructure one needs also enable actual io controlling logic policy enabling proportional weight division disk bandwidth cfq seti config_cfq_group_iosched enabling throttling policy set config_blk_throttle see documentation cgroups blkio controller txt information',
#  'blk dev initrd initial ram filesystem ram disk initramfs initrd support initial ram filesystem ramfs loaded boot loader loadlin lilo mounted root normal boot procedure typically used load modules needed mount real root file system etc see file documentation initrd txt details ram disk support blk_dev_ram also included also enables initial ram disk initrd support adds 15 kbytes architectures kernel size unsure say']

# %% [markdown]
# Compute term frequency

# %%
# Compute word count
cQ = CountVectorizer(min_df=1)
tf_Query = cQ.fit_transform(queries)
feature_Query = cQ.get_feature_names()
tf_Query = tf_Query.toarray()

# Convert count to frequency
newTF = []
for doc in tf_Query:
    #print(doc)
    tmp = []
    for ele in doc:
        tmp.append(ele/sum(doc))
    newTF.append(tmp)
tf_Query = newTF

# %% [markdown]
# Find similar documents

# %%
q = 1
for doc in tf_Query:
    
    print("Query ",q,":")
    q += 1
    
    # Term-freq dictionary for queries
    Query_tf = {term: tf for term, tf in zip(feature_Query, list(doc))}
    top5 = sorted(Query_tf.items(), key=operator.itemgetter(1), reverse=True)
    top5 = [i[0] for i in top5]
    print(", ".join(top5[:10]))
    
    # Vector representation of query
    vec = []
    for k, v in idfLst.items():
        if k in Query_tf:
            vec.append(v * Query_tf[k])
        else:
            vec.append(0)
            
    # Find the most similar doc
    ranker = {}
    top5W = {}
    index = 0
    for i in tfidf:
        sim = 1 - spatial.distance.cosine(i, vec)
        if sim > 0:
            ranker[index] = sim
            
            # Top five word
            top5 = {term: tfidf for term, tfidf in zip(b2, list(i))}
            top5 = sorted(top5.items(), key=operator.itemgetter(1), reverse=True)
            top5W[index] = [i[0] for i in top5]
        
        index += 1
        
    # Descendent sort
    sorted_ranker = sorted(ranker.items(), key=operator.itemgetter(1), reverse=True)
    
    # Result
    for res in sorted_ranker[:10]:
        print(filename[res[0]], ";", res[1], ";", ", ".join(top5W[res[0]][:10]))
    print()
# Out:
# Query  1 :
# task, cpu, delay, accounting, acct, block, collect, completion, enable, etc
# document1138.txt ; 0.2671735982121881 ; delay, timer, azf3328, countdown, snd, chip, flags, value, lock, minimum
# document1498.txt ; 0.15537632182444716 ; ttm, tt, user, space, pages, populate, task, start, valid, address
# document343.txt ; 0.13720533381246902 ; cpu, u64, tt, be128, gf128mul, bbe, table, 120, able, ablkcipher
# document2325.txt ; 0.12988264078067457 ; cpumask, cpu, pcrypt, padata, cb, rcu, mask, weight, parallel, bh
# document2388.txt ; 0.12335718447124511 ; cpu, tfm, ctx, cipher, crypto, aead, instance, pcrypt, ictx, cpumask
# document363.txt ; 0.10454727464817082 ; be64, cpu, u64, bbe, tt, gf128mul, x8, be128, table, 120
# document355.txt ; 0.10437417297137674 ; be64, cpu, u64, lle, tt, gf128mul, x8, be128, table, 120
# document335.txt ; 0.10283396944397705 ; be64, cpu, u64, bbe, tt, be128, gf128mul, table, 120, able
# document1474.txt ; 0.10098368492473764 ; wait, bo, object, cpu, ttm, buffer, sleep, sync, access, erestartsys
# document719.txt ; 0.09259437698005446 ; srcp, cpumask, first, cpu, 120, able, ablkcipher, abort, abreq, ac
#
# Query  2 :
# io, block, controller, cgroup, allocation, also, bandwidth, cfq, controlling, disk
# document1227.txt ; 0.2711422497300906 ; io, opl, als4k, game, mpu, sb, iobase, gcr, legacy, addr
# document1683.txt ; 0.20169584777455984 ; io, outw, gpio, dir, gpo, ring, bus, primary, ctrl, m3
# document796.txt ; 0.19963832243016677 ; io, reg, udelay, u8, cs5530, inb, outb, mixer, devinit, read
# document1681.txt ; 0.19243819995127565 ; dest, io, ctrl, inw, outw, ring, bus, codec, addr, remote
# document1688.txt ; 0.16918814569606322 ; gpio, io, outw, omnibook, val, mask, gpi, direction, vol, m3
# document1198.txt ; 0.1606187529863803 ; regs, saved, io, addr, reg, resume, azf3328, dbgpm, count, inl
# document1043.txt ; 0.16021650048812153 ; gameport, port, ensoniq, io, gp, ens137x, es, ctrl, region, joy
# document1197.txt ; 0.14059388297086484 ; regs, saved, io, addr, reg, suspend, azf3328, dbgpm, count, inl
# document1690.txt ; 0.14011572445800846 ; enable, assp, hv, val, host, io, mpu401, m3, outb, ctrl
# document543.txt ; 0.13627927352048774 ; uart, base, ok, io, scr, failed, comes, lcr, tests, inb
#
# Query  3 :
# ram, initrd, disk, initial, support, also, boot, file, filesystem, root
# document987.txt ; 0.1872206424618994 ; es, src, dis, ram, ensoniq, es1371, reg, addro, r1, smprate
# document2196.txt ; 0.16930914173043654 ; dxs, support, param, module, 120, able, ablkcipher, abort, abreq, ac
# document41.txt ; 0.1259792117690518 ; root, proc, card, mutex, link, info, disconnect, snd, de, called
# document40.txt ; 0.12289389286873686 ; root, proc, card, link, mutex, id, info, change, symlink, name
# document39.txt ; 0.1095846325382488 ; proc, card, root, symlink, id, name, dir, strcmp, snd, called
# document1278.txt ; 0.10813425443912228 ; drm, modeset, vblank, crtc, pre, support, dev, device, 120, able
# document351.txt ; 0.10720806428950547 ; mfile, file, card, files, list, add, linked, lock, spin, adds
# document42.txt ; 0.10482092865037407 ; card, proc, root, resources, info, free, called, file, snd, release
# document2495.txt ; 0.10320868336229494 ; efi, memmap, boot, params, memdesc, x86, info, desc, size, memblock
# document984.txt ; 0.10015060073420567 ; ensoniq, src, es, smprate, ready, wait, resched, cond, ram, poll
