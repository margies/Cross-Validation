# %%
from sklearn.feature_selection import RFECV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils import shuffle
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

import numpy as np
import pandas as pd

# %% [markdown]
# ### Read dataset from file

# %%
y = []
x = []
with open("./datafile.txt") as dt:
    for line in dt:
        line = line.strip().split(" ")
        
        if line[0] == "+1":
            y.append(1)
        else:
            y.append(0)
        tmp = []
        for i in range(1, 51):
            #print(line[i])
            tmp.append(line[i].split(":")[1])
        
        x.append(tmp)

# %%
feature_name = ["T1","T2","T3","T4","T5","PE1","PE2","PE3","PE4","PE5","PE6","PE7","PE8","PE9","PE10","R1","R2","R3","R4","R5","R6","R7","R8","R9","R10","SS1","SS2","SS3","SS4","SS5","SS6","G1","G2","G3","G4","G5","G6","G7","G8","G9","G10","G11","C1","C2","C3","C4","C5","C6","C7","C8"]

# %% [markdown]
# ### Feature selection

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
res = {}
estimator = LogisticRegression()
selector = RFECV(estimator, step=1, cv=10, n_jobs=10)
selector = selector.fit(X, Y)
res['LR'] = {k: v for k, v in zip(feature_name, selector.support_) }
estimator = DecisionTreeClassifier()
selector = RFECV(estimator, step=1, cv=10, n_jobs=10)
selector = selector.fit(X, Y)
res['DT'] = {k: v for k, v in zip(feature_name, selector.support_) }
pd.DataFrame(res)
# Out:
#          DT     LR
# C1    False   True
# C2    False   True
# C3    False   True
# C4    False   True
# C5    False   True
# C6    False   True
# C7    False   True
# C8    False   True
# G1    False   True
# G10    True   True
# G11   False   True
# G2    False   True
# G3     True   True
# G4    False   True
# G5     True   True
# G6    False   True
# G7    False   True
# G8    False   True
# G9    False   True
# PE1    True   True
# PE10  False   True
# PE2    True   True
# PE3   False   True
# PE4   False   True
# PE5   False   True
# PE6   False   True
# PE7   False   True
# PE8   False   True
# PE9   False   True
# R1    False   True
# R10   False   True
# R2    False   True
# R3    False   True
# R4    False   True
# R5    False   True
# R6    False   True
# R7    False   True
# R8    False   True
# R9    False   True
# SS1   False   True
# SS2   False   True
# SS3   False   True
# SS4   False   True
# SS5   False   True
# SS6   False   True
# T1    False   True
# T2    False   True
# T3     True   True
# T4    False  False
# T5     True   True

# %% [markdown]
# ### SVM

# %% [markdown]
# #### 10-Fold CV w/ SVM using linear kernel

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = KFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
        
    clf = SVC(kernel="linear")
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5         6         7  \
# ACC  0.700000  0.700000  0.750000  0.600000  0.800000  0.650000  0.650000
# F1   0.727273  0.727273  0.736842  0.600000  0.800000  0.695652  0.666667
# PRE  0.615385  0.666667  0.700000  0.461538  0.727273  0.727273  0.538462
# REC  0.888889  0.800000  0.777778  0.857143  0.888889  0.666667  0.875000
#
#             8         9        10       AVG
# ACC  0.800000  0.550000  0.700000  0.690000
# F1   0.866667  0.666667  0.750000  0.723704
# PRE  0.812500  0.692308  0.642857  0.658426
# REC  0.928571  0.642857  0.900000  0.822579

# %% [markdown]
# #### 10-Fold Stratified CV w/ SVM using linear kernel

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = StratifiedKFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X, Y):
    
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
     
    clf = SVC(kernel="linear")
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5         6         7  \
# ACC  0.714286  0.714286  0.850000  0.750000  0.750000  0.600000  0.700000
# F1   0.769231  0.785714  0.857143  0.782609  0.782609  0.636364  0.769231
# PRE  0.666667  0.647059  0.818182  0.692308  0.692308  0.583333  0.625000
# REC  0.909091  1.000000  0.900000  0.900000  0.900000  0.700000  1.000000
#
#             8         9        10       AVG
# ACC  0.600000  0.526316  0.736842  0.694173
# F1   0.692308  0.608696  0.761905  0.744581
# PRE  0.562500  0.538462  0.727273  0.655309
# REC  0.900000  0.700000  0.800000  0.870909

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### 10-Fold CV w/ Logistic Regression

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = KFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    clf = LogisticRegression()
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5         6         7  \
# ACC  0.700000  0.650000  0.600000  0.750000  0.500000  0.650000  0.650000
# F1   0.785714  0.695652  0.692308  0.814815  0.500000  0.695652  0.740741
# PRE  0.733333  0.727273  0.562500  0.785714  0.416667  0.615385  0.714286
# REC  0.846154  0.666667  0.900000  0.846154  0.625000  0.800000  0.769231
#
#             8         9        10       AVG
# ACC  0.650000  0.600000  0.450000  0.620000
# F1   0.695652  0.600000  0.521739  0.674227
# PRE  0.571429  0.428571  0.400000  0.595516
# REC  0.888889  1.000000  0.750000  0.809209

# %% [markdown]
# #### 10-Fold Stratified CV w/ Logistic Regression

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = StratifiedKFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X, Y):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    clf = LogisticRegression()
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5     6         7  \
# ACC  0.761905  0.666667  0.750000  0.550000  0.550000  0.65  0.750000
# F1   0.800000  0.720000  0.800000  0.689655  0.571429  0.72  0.782609
# PRE  0.714286  0.642857  0.666667  0.526316  0.545455  0.60  0.692308
# REC  0.909091  0.818182  1.000000  1.000000  0.600000  0.90  0.900000
#
#             8         9        10       AVG
# ACC  0.700000  0.473684  0.473684  0.632594
# F1   0.727273  0.545455  0.545455  0.690187
# PRE  0.666667  0.500000  0.500000  0.605455
# REC  0.800000  0.600000  0.600000  0.812727

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### 10-Fold CV w/ Random Forest

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = KFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    clf = RandomForestClassifier(max_depth=5, n_estimators=20, random_state=0, n_jobs=5)
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5         6         7  \
# ACC  0.750000  0.800000  0.750000  0.800000  0.800000  0.600000  0.550000
# F1   0.814815  0.875000  0.761905  0.818182  0.818182  0.692308  0.470588
# PRE  0.785714  0.823529  0.666667  0.692308  0.900000  0.562500  0.400000
# REC  0.846154  0.933333  0.888889  1.000000  0.750000  0.900000  0.571429
#
#             8         9        10       AVG
# ACC  0.700000  0.500000  0.850000  0.710000
# F1   0.750000  0.285714  0.857143  0.714384
# PRE  0.692308  0.285714  0.750000  0.655874
# REC  0.818182  0.285714  1.000000  0.799370

# %% [markdown]
# #### 10-Fold Stratified CV w/ Random Forest

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = StratifiedKFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X, Y):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    clf = RandomForestClassifier(max_depth=5, n_estimators=20, random_state=0, n_jobs=5)
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5         6    7  \
# ACC  0.714286  0.714286  0.700000  0.700000  0.750000  0.800000  0.8
# F1   0.769231  0.750000  0.750000  0.666667  0.782609  0.818182  0.8
# PRE  0.666667  0.692308  0.642857  0.750000  0.692308  0.750000  0.8
# REC  0.909091  0.818182  0.900000  0.600000  0.900000  0.900000  0.8
#
#             8         9        10       AVG
# ACC  0.550000  0.736842  0.736842  0.720226
# F1   0.608696  0.782609  0.782609  0.751060
# PRE  0.538462  0.692308  0.692308  0.691722
# REC  0.700000  0.900000  0.900000  0.832727

# %% [markdown]
# ### Adaboost

# %% [markdown]
# #### 10-Fold CV w/ adaBoost

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = KFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    est = LogisticRegression()
    clf = AdaBoostClassifier(learning_rate=0.01, base_estimator=est)
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5       6         7  \
# ACC  0.600000  0.750000  0.550000  0.800000  0.800000  0.6500  0.700000
# F1   0.666667  0.761905  0.571429  0.833333  0.866667  0.7200  0.750000
# PRE  0.500000  0.615385  0.600000  0.833333  0.764706  0.5625  0.642857
# REC  1.000000  1.000000  0.545455  0.833333  1.000000  1.0000  0.900000
#
#             8         9        10       AVG
# ACC  0.550000  0.600000  0.650000  0.665000
# F1   0.640000  0.714286  0.758621  0.728291
# PRE  0.470588  0.588235  0.647059  0.622466
# REC  1.000000  0.909091  0.916667  0.910455

# %% [markdown]
# #### 10-Fold Stratified CV w/ adaBoost

# %%
X = np.array(x, dtype="float64")
Y = np.array(y)
kf = StratifiedKFold(n_splits=10, shuffle=True)
record = {}
fold = 1
for train_index, test_index in kf.split(X, Y):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    
    est = LogisticRegression()
    clf = AdaBoostClassifier(learning_rate=0.01, base_estimator=est)
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    acc = accuracy_score(y_test, pred)
    pre = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    record[fold] = {"ACC":acc, "PRE":pre, "REC": rec, "F1": f1}
    fold += 1
    
print("10-Fold CV Finished!")
record["AVG"] ={
    "ACC":np.mean([v['ACC'] for k, v in record.items()]), 
    "PRE":np.mean([v['PRE'] for k, v in record.items()]),  
    "REC": np.mean([v['REC'] for k, v in record.items()]),  
    "F1": np.mean([v['F1'] for k, v in record.items()])
}
# Out:
# 10-Fold CV Finished!

# %%
pd.DataFrame(record)
# Out:
#             1         2         3         4         5         6         7  \
# ACC  0.619048  0.761905  0.700000  0.750000  0.600000  0.600000  0.700000
# F1   0.714286  0.800000  0.727273  0.800000  0.692308  0.692308  0.750000
# PRE  0.588235  0.714286  0.666667  0.666667  0.562500  0.562500  0.642857
# REC  0.909091  0.909091  0.800000  1.000000  0.900000  0.900000  0.900000
#
#             8         9        10       AVG
# ACC  0.800000  0.684211  0.578947  0.679411
# F1   0.833333  0.750000  0.714286  0.747379
# PRE  0.714286  0.642857  0.555556  0.631641
# REC  1.000000  0.900000  1.000000  0.921818

# %%
clf.feature_importances_
# Out:
# array([0.01473701, 0.05516657, 0.26068903, 0.07875163, 0.05438041,
#        0.08016524, 0.03463198, 0.        , 0.        , 0.        ,
#        0.01178961, 0.        , 0.        , 0.00631586, 0.        ,
#        0.        , 0.05663701, 0.02094207, 0.        , 0.        ,
#        0.01105276, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.07979315,
#        0.01913898, 0.        , 0.        , 0.        , 0.02873718,
#        0.02110072, 0.        , 0.        , 0.        , 0.03403614,
#        0.0469776 , 0.01842127, 0.        , 0.        , 0.        ,
#        0.01473701, 0.        , 0.05179875, 0.        , 0.        ])
